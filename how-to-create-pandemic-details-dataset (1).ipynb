# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_epidemics")
df
# Out:
# [    Rank                 Epidemics/pandemics                       Disease  \
#  0      1                         Black Death                Bubonic plague
#  1      2                         Spanish flu              Influenza A/H1N1
#  2      3                 Plague of Justinian                Bubonic plague
#  3      4                   HIV/AIDS epidemic                      HIV/AIDS
#  4      5                   COVID-19 pandemic                      COVID-19
#  5      6               Third plague pandemic                Bubonic plague
#  6      7    Cocoliztli epidemic of 1545–1548                    Cocoliztli
#  7      8                     Antonine Plague           Smallpox or measles
#  8      9       1520 Mexico smallpox epidemic                      Smallpox
#  9     10    1918–1922 Russia typhus epidemic                        Typhus
#  10    11        1957–1958 influenza pandemic              Influenza A/H2N2
# ...

# %%
df[0]
# Out:
#     Rank                 Epidemics/pandemics                       Disease  \
# 0      1                         Black Death                Bubonic plague
# 1      2                         Spanish flu              Influenza A/H1N1
# 2      3                 Plague of Justinian                Bubonic plague
# 3      4                   HIV/AIDS epidemic                      HIV/AIDS
# 4      5                   COVID-19 pandemic                      COVID-19
# 5      6               Third plague pandemic                Bubonic plague
# 6      7    Cocoliztli epidemic of 1545–1548                    Cocoliztli
# 7      8                     Antonine Plague           Smallpox or measles
# 8      9       1520 Mexico smallpox epidemic                      Smallpox
# 9     10    1918–1922 Russia typhus epidemic                        Typhus
# 10    11        1957–1958 influenza pandemic              Influenza A/H2N2
# ...

# %%
new_data=df[0]

# %%
new_data.drop(['Regional population lost','Global population lost'],axis=1,inplace=True)

# %%
new_data
# Out:
#     Rank                 Epidemics/pandemics                       Disease  \
# 0      1                         Black Death                Bubonic plague
# 1      2                         Spanish flu              Influenza A/H1N1
# 2      3                 Plague of Justinian                Bubonic plague
# 3      4                   HIV/AIDS epidemic                      HIV/AIDS
# 4      5                   COVID-19 pandemic                      COVID-19
# 5      6               Third plague pandemic                Bubonic plague
# 6      7    Cocoliztli epidemic of 1545–1548                    Cocoliztli
# 7      8                     Antonine Plague           Smallpox or measles
# 8      9       1520 Mexico smallpox epidemic                      Smallpox
# 9     10    1918–1922 Russia typhus epidemic                        Typhus
# 10    11        1957–1958 influenza pandemic              Influenza A/H2N2
# ...

# %%
df[1]
# Out:
#                                             Event  \
# 0                       1350 BC plague of Megiddo
# 1                                Plague of Athens
# 2                                 412 BC epidemic
# 3                                 Antonine Plague
# 4                                  Jian'an Plague
# ..                                            ...
# 248            2020 Nigeria yellow fever epidemic
# 249              2021 India black fungus epidemic
# 250  2022 hepatitis of unknown origin in children
# 251                  2022–2023 monkeypox outbreak
# 252                    2022 Uganda Ebola outbreak
#
#                              Date                                  Location  \
# 0                         1350 BC                   Megiddo, land of Canaan
# 1                      430–426 BC            Greece, Libya, Egypt, Ethiopia
# 2                          412 BC  Greece (Northern Greece, Roman Republic)
# ...

# %%
data_old=df[1]

# %%
data_old.drop('Ref.',axis=1,inplace=True)
data_old
# Out:
#                                             Event  \
# 0                       1350 BC plague of Megiddo
# 1                                Plague of Athens
# 2                                 412 BC epidemic
# 3                                 Antonine Plague
# 4                                  Jian'an Plague
# ..                                            ...
# 248            2020 Nigeria yellow fever epidemic
# 249              2021 India black fungus epidemic
# 250  2022 hepatitis of unknown origin in children
# 251                  2022–2023 monkeypox outbreak
# 252                    2022 Uganda Ebola outbreak
#
#                              Date                                  Location  \
# 0                         1350 BC                   Megiddo, land of Canaan
# 1                      430–426 BC            Greece, Libya, Egypt, Ethiopia
# 2                          412 BC  Greece (Northern Greece, Roman Republic)
# ...

# %%
new_data.columns
# Out:
# Index(['Rank', 'Epidemics/pandemics', 'Disease', 'Death toll', 'Date',
#        'Location'],
#       dtype='object')

# %%
data_old.rename(columns={'Event':'Epidemics/pandemics',
                'Date':'Date',
                'Location':'Location',
                'Death toll (estimate)':'Death toll',
                'Disease':'Disease'},inplace=True)

# %%
data_old
# Out:
#                               Epidemics/pandemics  \
# 0                       1350 BC plague of Megiddo
# 1                                Plague of Athens
# 2                                 412 BC epidemic
# 3                                 Antonine Plague
# 4                                  Jian'an Plague
# ..                                            ...
# 248            2020 Nigeria yellow fever epidemic
# 249              2021 India black fungus epidemic
# 250  2022 hepatitis of unknown origin in children
# 251                  2022–2023 monkeypox outbreak
# 252                    2022 Uganda Ebola outbreak
#
#                              Date                                  Location  \
# 0                         1350 BC                   Megiddo, land of Canaan
# 1                      430–426 BC            Greece, Libya, Egypt, Ethiopia
# 2                          412 BC  Greece (Northern Greece, Roman Republic)
# ...

# %%
data_old.columns
# Out:
# Index(['Epidemics/pandemics', 'Date', 'Location', 'Disease', 'Death toll'], dtype='object')

# %%
new_data.drop('Rank',axis=1,inplace=True)

# %%
new_data.columns
# Out:
# Index(['Epidemics/pandemics', 'Disease', 'Death toll', 'Date', 'Location'], dtype='object')

# %%
old_data=data_old[['Epidemics/pandemics', 'Disease', 'Death toll', 'Date', 'Location']]

# %%
old_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Epidemics/pandemics  253 non-null    object
#  1   Disease              253 non-null    object
#  2   Death toll           253 non-null    object
#  3   Date                 253 non-null    object
#  4   Location             253 non-null    object
# dtypes: object(5)
# memory usage: 10.0+ KB

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Epidemics/pandemics  19 non-null     object
#  1   Disease              19 non-null     object
#  2   Death toll           19 non-null     object
#  3   Date                 19 non-null     object
#  4   Location             19 non-null     object
# dtypes: object(5)
# memory usage: 888.0+ bytes

# %%
final=new_data.append(old_data)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272 entries, 0 to 252
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Epidemics/pandemics  272 non-null    object
#  1   Disease              272 non-null    object
#  2   Death toll           272 non-null    object
#  3   Date                 272 non-null    object
#  4   Location             272 non-null    object
# dtypes: object(5)
# memory usage: 12.8+ KB

# %%
final.to_csv('pandemic-details-of-world.csv')
